# %% [markdown]
# ## NetCDF Exploration

# %%
import xarray as xr

# %%
data = xr.open_dataset('data/4km_SWE_Depth_NM.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14610, lat: 73, lon: 73)
# Coordinates:
#   * lat      (lat) float32 34.0 34.04 34.08 34.12 ... 36.88 36.92 36.96 37.0
#   * lon      (lon) float32 -107.0 -107.0 -106.9 -106.9 ... -104.1 -104.0 -104.0
#   * time     (time) datetime64[ns] 1981-10-01 1981-10-02 ... 2021-09-30
# Data variables:
#     SWE      (time, lat, lon) float32 ...
#     DEPTH    (time, lat, lon) float32 ...

# %%
data_pt = data['SWE'].sel(lat=32,lon=-103,method='nearest')

# %%
data_pandas = data_pt.to_pandas()
data_pandas.head()
# Out:
# time
# 1981-10-01    0.0
# 1981-10-02    0.0
# 1981-10-03    0.0
# 1981-10-04    0.0
# 1981-10-05    0.0
# dtype: float32

# %%
data_pt
# Out:
# <xarray.DataArray 'SWE' (time: 14610)>
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
# Coordinates:
#     lat      float32 34.0
#     lon      float32 -104.0
#   * time     (time) datetime64[ns] 1981-10-01 1981-10-02 ... 2021-09-30
# Attributes:
#     long_name:     Snow Water Equivalent
#     grid_mapping:  crs
#     units:         millimeters h20
